# %% [markdown]
# How many women who developed GDM did we correctly identify? (Recall)
# How often are our positive predictions correct? (Precision)
# How well does the model separate the two classes overall? (ROC-AUC)
# How does performance change across thresholds? (ROC and Precision–Recall curves)
# Are the predicted probabilities well calibrated? (Calibration curve, Brier score)
